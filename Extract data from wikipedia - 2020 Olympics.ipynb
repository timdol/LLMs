# %% [markdown]
# ### This implements a lot of the example here:
# https://github.com/openai/openai-cookbook/blob/57024c70cff473fb520105e9aea3ab4e514be0df/examples/fine-tuned_qa/olympics-1-collect-data.ipynb
#
#
# ### The purpose of this notebook is to build a dataset of text that we can use elsewhere to demonstrate question answering using embeddings

# %%
import pandas as pd
import wikipedia

# For wikipedia API documentation see here: https://wikipedia.readthedocs.io/en/latest/code.html

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /home/tim/anaconda3/lib/python3.8/site-packages (4.26.0)
# Requirement already satisfied: packaging>=20.0 in /home/tim/anaconda3/lib/python3.8/site-packages (from transformers) (20.9)
# Requirement already satisfied: regex!=2019.12.17 in /home/tim/anaconda3/lib/python3.8/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in /home/tim/anaconda3/lib/python3.8/site-packages (from transformers) (1.20.1)
# Requirement already satisfied: requests in /home/tim/anaconda3/lib/python3.8/site-packages (from transformers) (2.28.2)
# Requirement already satisfied: tqdm>=4.27 in /home/tim/anaconda3/lib/python3.8/site-packages (from transformers) (4.59.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/tim/anaconda3/lib/python3.8/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/tim/anaconda3/lib/python3.8/site-packages (from transformers) (0.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/tim/anaconda3/lib/python3.8/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: filelock in /home/tim/anaconda3/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/tim/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/tim/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/tim/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tim/.local/lib/python3.8/site-packages (from requests->transformers) (2019.3.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tim/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/tim/anaconda3/lib/python3.8/site-packages (from requests->transformers) (1.26.4)

# %%
import re
from typing import Set
from transformers import GPT2TokenizerFast

import numpy as np
from nltk.tokenize import sent_tokenize

import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/tim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def get_wiki_page(title):
    """
    Get the wikipedia page given a title
    """
    try:
        print(f"Fetching page '{title}'")
        return wikipedia.page(title)
    except wikipedia.exceptions.DisambiguationError as e:
        return wikipedia.page(e.options[0])
    except wikipedia.exceptions.PageError as e:
        return None

def recursively_find_all_pages(titles, titles_so_far=set(), title_filter=None):
    """
    Recursively find all the pages that are linked to the Wikipedia titles in the list
    """
    all_pages = []
    
    titles = list(set(titles) - titles_so_far)
    if title_filter:
        titles = title_filter(titles)
    titles_so_far.update(titles)
    for title in titles:
        page = get_wiki_page(title)
        if page is None:
            continue
        all_pages.append(page)

        new_pages = recursively_find_all_pages(page.links, titles_so_far, title_filter)
        for pg in new_pages:
            if pg.title not in [p.title for p in all_pages]:
                all_pages.append(pg)
        titles_so_far.update(page.links)
    return all_pages

# %%
# Define a filter to limit pages to the 2020 summer olympics,
# and find all matching wikipedia pages--
# THIS TAKES A WHILE

def filter_olympic_2020_titles(titles):
    """
    Get the titles which are related to Olympic games hosted in 2020, given a list of titles
    """
    titles = [title for title in titles if '2020' in title and 'olympi' in title.lower() and 'summer' in title.lower()]
    
    return titles

pages = recursively_find_all_pages(["2020 Summer Olympics"], title_filter=filter_olympic_2020_titles)
len(pages)
# Out:
# Fetching page '2020 Summer Olympics'
# Fetching page 'Romania at the 2020 Summer Olympics'
# Fetching page 'Archery at the 2020 Summer Olympics - Qualification'
# Fetching page 'List of archers at the 2020 Summer Olympics'
# Fetching page 'List of taekwondo practitioners at the 2020 Summer Olympics'
# Fetching page 'Taekwondo at the 2020 Summer Olympics – Men's 80 kg'
# Fetching page 'Taekwondo at the 2020 Summer Olympics – Women's 67 kg'
# Fetching page 'Taekwondo at the 2020 Summer Olympics – Women's 49 kg'
# Fetching page 'Taekwondo at the 2020 Summer Olympics – Women's 57 kg'
# Fetching page 'Taekwondo at the 2020 Summer Olympics – Men's 58 kg'
# Fetching page 'Taekwondo at the 2020 Summer Olympics – Men's 68 kg'
# Fetching page 'Taekwondo at the 2020 Summer Olympics – Men's +80 kg'
# Fetching page 'Taekwondo at the 2020 Summer Olympics – Women's +67 kg'
# Fetching page 'List of weightlifters at the 2020 Summer Olympics'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Men's 96 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Women's +87 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Women's 87 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Women's 49 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Women's 55 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Women's 64 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Women's 76 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Women's 59 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Men's 67 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Men's 73 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Men's 61 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Men's +109 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Men's 109 kg'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Men's 81 kg'
# Fetching page 'List of wrestlers at the 2020 Summer Olympics'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Women's freestyle 68 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's Greco-Roman 77 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's Greco-Roman 60 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's freestyle 125 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's freestyle 65 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's Greco-Roman 67 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's freestyle 86 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's freestyle 57 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's freestyle 74 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Women's freestyle 76 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's Greco-Roman 87 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Women's freestyle 57 kg'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's Greco-Roman 97 kg'
# Fetching page 'List of table tennis players at the 2020 Summer Olympics'
# Fetching page 'Table tennis at the 2020 Summer Olympics – Men's team'
# Fetching page 'List of shooters at the 2020 Summer Olympics'
# Fetching page 'Shooting at the 2020 Summer Olympics – Men's 10 metre air pistol'
# Fetching page 'Shooting at the 2020 Summer Olympics – Mixed trap team'
# Fetching page 'Shooting at the 2020 Summer Olympics – Women's skeet'
# Fetching page 'Shooting at the 2020 Summer Olympics – Men's trap'
# Fetching page 'Shooting at the 2020 Summer Olympics – Men's 50 metre rifle three positions'
# Fetching page 'Shooting at the 2020 Summer Olympics – Men's skeet'
# Fetching page 'Shooting at the 2020 Summer Olympics – Men's 25 metre rapid fire pistol'
# Fetching page 'Shooting at the 2020 Summer Olympics – Women's 25 metre pistol'
# Fetching page 'Shooting at the 2020 Summer Olympics – Women's 10 metre air pistol'
# Fetching page 'Shooting at the 2020 Summer Olympics – Mixed 10 metre air rifle team'
# Fetching page 'Shooting at the 2020 Summer Olympics – Men's 10 metre air rifle'
# Fetching page 'Shooting at the 2020 Summer Olympics – Women's 50 metre rifle three positions'
# Fetching page 'Shooting at the 2020 Summer Olympics – Mixed 10 metre air pistol team'
# Fetching page 'Shooting at the 2020 Summer Olympics – Women's trap'
# Fetching page 'List of skateboarders at the 2020 Summer Olympics'
# Fetching page 'Skateboarding at the 2020 Summer Olympics – Men's park'
# Fetching page 'Skateboarding at the 2020 Summer Olympics – Men's street'
# Fetching page 'Skateboarding at the 2020 Summer Olympics – Women's park'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's BMX freestyle'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's omnium'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's omnium'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's BMX freestyle'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's BMX'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's BMX racing'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's team pursuit'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's sprint'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's BMX'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's Madison'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's team pursuit'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's road time trial'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's individual road race'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's team sprint'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's road time trial'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's team sprint'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's BMX racing'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's sprint'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's Madison'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's keirin'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's keirin'
# Fetching page 'Skateboarding at the 2020 Summer Olympics – Women's street'
# Fetching page 'List of fencers at the 2020 Summer Olympics'
# Fetching page 'Fencing at the 2020 Summer Olympics – Men's team sabre'
# Fetching page 'Fencing at the 2020 Summer Olympics – Men's team foil'
# Fetching page 'Fencing at the 2020 Summer Olympics – Men's foil'
# Fetching page 'Fencing at the 2020 Summer Olympics – Women's team foil'
# Fetching page 'Fencing at the 2020 Summer Olympics – Men's team épée'
# Fetching page 'Fencing at the 2020 Summer Olympics – Women's sabre'
# Fetching page 'Fencing at the 2020 Summer Olympics – Women's team sabre'
# Fetching page 'Fencing at the 2020 Summer Olympics – Women's foil'
# Fetching page 'Fencing at the 2020 Summer Olympics – Men's épée'
# Fetching page 'Fencing at the 2020 Summer Olympics – Women's team épée'
# Fetching page 'List of Beach volleyball players at the 2020 Summer Olympics'
# Fetching page 'Beach volleyball at the 2020 Summer Olympics – Women's tournament'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's tournament'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's South American qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Women's Asian qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Women's North American qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Women's European qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Women's European qualification squads'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's European qualification squads'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Women's South American qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Women's African qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's African qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's North American qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's Asian qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's European qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Women's tournament'
# Fetching page 'Beach volleyball at the 2020 Summer Olympics – Men's tournament'
# Fetching page 'Beach volleyball at the 2020 Summer Olympics'
# Fetching page 'List of sailors at the 2020 Summer Olympics'
# Fetching page 'List of triathletes at the 2020 Summer Olympics'
# Fetching page 'Triathlon at the 2020 Summer Olympics – Mixed relay'
# Fetching page 'Triathlon at the 2020 Summer Olympics – Women's'
# Fetching page 'List of canoeists at the 2020 Summer Olympics'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Women's K-2 500 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Women's K-1 500 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Women's slalom C-1'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Men's K-2 1000 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Women's slalom K-1'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Women's C-1 200 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Men's slalom C-1'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Men's K-1 200 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Women's K-4 500 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Women's C-2 500 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Men's K-4 500 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Women's K-1 200 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Men's K-1 1000 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Men's slalom K-1'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Men's C-1 1000 metres'
# Fetching page 'List of surfers at the 2020 Summer Olympics'
# Fetching page 'Surfing at the 2020 Summer Olympics – Men's shortboard'
# Fetching page 'Surfing at the 2020 Summer Olympics – Women's shortboard'
# Fetching page 'List of badminton players at the 2020 Summer Olympics'
# Fetching page 'List of boxers at the 2020 Summer Olympics'
# Fetching page 'List of swimmers at the 2020 Summer Olympics'
# Fetching page 'Artistic swimming at the 2020 Summer Olympics – Women's team'
# Fetching page 'Judo at the 2020 Summer Olympics – Women's 63 kg'
# Fetching page 'Judo at the 2020 Summer Olympics – Men's 60 kg'
# Fetching page 'Judo at the 2020 Summer Olympics – Men's 90 kg'
# Fetching page 'Judo at the 2020 Summer Olympics – Women's +78 kg'
# Fetching page 'Judo at the 2020 Summer Olympics – Women's 70 kg'
# Fetching page 'Judo at the 2020 Summer Olympics – Mixed team'
# Fetching page 'Judo at the 2020 Summer Olympics – Women's 48 kg'
# Fetching page 'Judo at the 2020 Summer Olympics – Women's 78 kg'
# Fetching page 'Judo at the 2020 Summer Olympics – Men's 66 kg'
# Fetching page 'Diving at the 2020 Summer Olympics – Women's synchronized 3 metre springboard'
# Fetching page 'Diving at the 2020 Summer Olympics – Men's synchronized 3 metre springboard'
# Fetching page 'Sailing at the 2020 Summer Olympics – 49erFX'
# Fetching page 'Sailing at the 2020 Summer Olympics – Women's 470'
# Fetching page 'Sailing at the 2020 Summer Olympics – 49er FX'
# Fetching page 'Sailing at the 2020 Summer Olympics – Laser'
# Fetching page 'Sailing at the 2020 Summer Olympics – Men's RS:X'
# Fetching page 'Sailing at the 2020 Summer Olympics – Nacra 17'
# Fetching page 'Sailing at the 2020 Summer Olympics – Men's 470'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 4 × 100 metre medley relay'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 4 × 200 metre freestyle relay'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 200 metre butterfly'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 400 metre freestyle'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 800 metre freestyle'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 1500 metre freestyle'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 200 metre butterfly'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 400 metre individual medley'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 200 metre breaststroke'
# Fetching page 'Golf at the 2020 Summer Olympics – Men's individual'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's pole vault'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's triple jump'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 4 × 100 metres relay'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 20 kilometres walk'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's long jump'
# Fetching page 'Athletics at the 2020 Summer Olympics – Mixed 4 × 400 metres relay'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's hammer throw'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 100 metres hurdles'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 20 kilometres walk'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 1500 metres'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's triple jump'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 400 metres hurdles'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's discus throw'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 110 metres hurdles'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 4 × 400 metres relay'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 400 metres'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's pole vault'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 400 metre freestyle'
# Fetching page 'Basketball at the 2020 Summer Olympics – Women's tournament'
# Fetching page 'Sport climbing at the 2020 Summer Olympics – Men's combined'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 4 × 100 metre medley relay'
# Fetching page 'Artistic swimming at the 2020 Summer Olympics – Women's duet'
# Fetching page 'Equestrian at the 2020 Summer Olympics – Individual eventing'
# Fetching page 'Equestrian at the 2020 Summer Olympics – Team eventing'
# Fetching page 'Equestrian at the 2020 Summer Olympics – Team jumping'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 100 metre backstroke'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 200 metre backstroke'
# Fetching page 'Diving at the 2020 Summer Olympics – Women's 10 metre platform'
# Fetching page 'Sailing at the 2020 Summer Olympics – Laser Radial'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 100 metre breaststroke'
# Fetching page 'Badminton at the 2020 Summer Olympics – Women's singles'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 5000 metres'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 200 metres'
# Fetching page 'Boxing at the 2020 Summer Olympics – Women's flyweight'
# Fetching page 'Boxing at the 2020 Summer Olympics – Men's lightweight'
# Fetching page 'Boxing at the 2020 Summer Olympics – Men's super heavyweight'
# Fetching page 'Boxing at the 2020 Summer Olympics – Women's lightweight'
# Fetching page 'Boxing at the 2020 Summer Olympics – Men's light heavyweight'
# Fetching page 'Boxing at the 2020 Summer Olympics – Men's middleweight'
# Fetching page 'Boxing at the 2020 Summer Olympics – Men's heavyweight'
# Fetching page 'Boxing at the 2020 Summer Olympics – Men's featherweight'
# Fetching page 'Tennis at the 2020 Summer Olympics – Men's singles'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 3000 metres steeplechase'
# Fetching page 'Judo at the 2020 Summer Olympics – Men's 100 kg'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 200 metre breaststroke'
# Fetching page 'Water polo at the 2020 Summer Olympics – Women's tournament'
# Fetching page 'Water polo at the 2020 Summer Olympics – Men's tournament'
# Fetching page 'Equestrian at the 2020 Summer Olympics – Individual jumping'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 10,000 metres'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's marathon 10 kilometre'
# Fetching page 'Judo at the 2020 Summer Olympics – Women's 57 kg'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 200 metre freestyle'
# Fetching page 'Football at the 2020 Summer Olympics – Women's tournament – Knockout stage'
# Fetching page 'Football at the 2020 Summer Olympics – Women's tournament – Final'
# Fetching page 'Football at the 2020 Summer Olympics – Men's tournament – Group D'
# Fetching page 'Football at the 2020 Summer Olympics – Men's tournament – Group A'
# Fetching page 'Football at the 2020 Summer Olympics – Women's tournament – Group G'
# Fetching page 'Football at the 2020 Summer Olympics – Women's tournament – Group F'
# Fetching page 'Football at the 2020 Summer Olympics – Women's qualification (CAF–CONMEBOL play-off)'
# Fetching page 'Football at the 2020 Summer Olympics – Men's tournament – Group C'
# Fetching page 'Football at the 2020 Summer Olympics – Men's tournament – Final'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 200 metre individual medley'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's artistic individual all-around'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's artistic qualification'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's rhythmic group all-around'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's floor'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's rhythmic individual all-around'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's rings'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's artistic team all-around'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's artistic qualification'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's trampoline'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's uneven bars'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's horizontal bar'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's floor'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's pommel horse'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's parallel bars'
# Fetching page 'Equestrian at the 2020 Summer Olympics – Team dressage'
# Fetching page 'Judo at the 2020 Summer Olympics – Men's 81 kg'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 5000 metres'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 4 × 200 metre freestyle relay'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's shot put'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's decathlon'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's trampoline'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 800 metres'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's heptathlon'
# Fetching page 'Rowing at the 2020 Summer Olympics – Women's single sculls'
# Fetching page 'Rowing at the 2020 Summer Olympics – Men's quadruple sculls'
# Fetching page 'Rowing at the 2020 Summer Olympics – Women's quadruple sculls'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 400 metre individual medley'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 10,000 metres'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 400 metres hurdles'
# Fetching page 'Diving at the 2020 Summer Olympics – Women's 3 metre springboard'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 3000 metres steeplechase'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's vault'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 4 × 100 metre freestyle relay'
# Fetching page 'Diving at the 2020 Summer Olympics – Men's 3 metre springboard'
# Fetching page 'Rowing at the 2020 Summer Olympics – Men's single sculls'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's marathon'
# Fetching page 'North Korea at the 2020 Summer Olympics'
# Fetching page 'Badminton at the 2020 Summer Olympics – Mixed doubles'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 4 × 400 metres relay'
# Fetching page 'Football at the 2020 Summer Olympics – Women's tournament – Group E'
# Fetching page 'Golf at the 2020 Summer Olympics – Women's individual'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's artistic team all-around'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's marathon'
# Fetching page 'Rugby sevens at the 2020 Summer Olympics – Women's tournament'
# Fetching page 'Football at the 2020 Summer Olympics – Women's tournament'
# Fetching page 'Sailing at the 2020 Summer Olympics – 49er'
# Fetching page 'Tennis at the 2020 Summer Olympics – Mixed doubles'
# Fetching page 'Tennis at the 2020 Summer Olympics – Men's doubles'
# Fetching page 'Swimming at the 2020 Summer Olympics – Mixed 4 × 100 metre medley relay'
# Fetching page 'Badminton at the 2020 Summer Olympics – Women's doubles'
# Fetching page 'Karate at the 2020 Summer Olympics – Men's +75 kg'
# Fetching page 'Karate at the 2020 Summer Olympics – Women's kata'
# Fetching page 'Karate at the 2020 Summer Olympics – Men's kata'
# Fetching page 'Karate at the 2020 Summer Olympics – Women's +61 kg'
# Fetching page 'Karate at the 2020 Summer Olympics – Women's 61 kg'
# Fetching page 'Karate at the 2020 Summer Olympics – Men's 75 kg'
# Fetching page 'Karate at the 2020 Summer Olympics – Men's 67 kg'
# Fetching page 'Karate at the 2020 Summer Olympics – Women's 55 kg'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's marathon 10 kilometre'
# Fetching page 'Badminton at the 2020 Summer Olympics – Men's singles'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 100 metre butterfly'
# Fetching page 'Sport climbing at the 2020 Summer Olympics – Women's combined'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 4 × 100 metres relay'
# Fetching page 'Boxing at the 2020 Summer Olympics – Men's welterweight'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 100 metres'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 800 metres'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 200 metres'
# Fetching page 'Rugby sevens at the 2020 Summer Olympics – Men's tournament'
# Fetching page 'Diving at the 2020 Summer Olympics – Men's synchronized 10 metre platform'
# Fetching page 'Rowing at the 2020 Summer Olympics – Men's lightweight double sculls'
# Fetching page 'Equestrian at the 2020 Summer Olympics – Individual dressage'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 800 metre freestyle'
# Fetching page 'Boxing at the 2020 Summer Olympics – Women's welterweight'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 4 × 100 metre freestyle relay'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 1500 metre freestyle'
# Fetching page 'Sailing at the 2020 Summer Olympics – Women's RS:X'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's javelin throw'
# Fetching page 'Diving at the 2020 Summer Olympics – Men's 10 metre platform'
# Fetching page 'Boxing at the 2020 Summer Olympics – Women's middleweight'
# Fetching page 'Diving at the 2020 Summer Olympics – Women's synchronized 10 metre platform'
# Fetching page 'Field hockey at the 2020 Summer Olympics – Men's tournament'
# Fetching page 'Field hockey at the 2020 Summer Olympics – Women's tournament'
# Fetching page 'Badminton at the 2020 Summer Olympics – Men's doubles'
# Fetching page 'Sailing at the 2020 Summer Olympics – Finn'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 200 metre individual medley'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's high jump'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 100 metre breaststroke'
# Fetching page 'List of equestrians at the 2020 Summer Olympics'
# Fetching page 'Basketball at the 2020 Summer Olympics – Men's team rosters'
# Fetching page 'Basketball at the 2020 Summer Olympics – Men's tournament'
# Fetching page 'Basketball at the 2020 Summer Olympics – Men's 3x3 tournament'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Women's team rosters'
# Fetching page 'Rugby sevens at the 2020 Summer Olympics – Men's team squads'
# Fetching page 'Softball at the 2020 Summer Olympics – Team squads'
# Fetching page 'List of tennis players at the 2020 Summer Olympics'
# Fetching page 'List of karateka at the 2020 Summer Olympics'
# Fetching page 'Baseball at the 2020 Summer Olympics – Team squads'
# Fetching page 'Rugby sevens at the 2020 Summer Olympics – Women's team squads'
# Fetching page 'List of divers at the 2020 Summer Olympics'
# Fetching page 'Field hockey at the 2020 Summer Olympics – Men's team squads'
# Fetching page 'List of judoka at the 2020 Summer Olympics'
# Fetching page 'List of modern pentathletes at the 2020 Summer Olympics'
# Fetching page 'Handball at the 2020 Summer Olympics – Men's team rosters'
# Fetching page 'Handball at the 2020 Summer Olympics – Women's tournament'
# Fetching page 'Handball at the 2020 Summer Olympics – Men's tournament'
# Fetching page 'Football at the 2020 Summer Olympics – Men's team squads'
# Fetching page 'List of gymnasts at the 2020 Summer Olympics'
# Fetching page 'List of cyclists at the 2020 Summer Olympics'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's road race'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's road race'
# Fetching page 'List of synchronized swimmers at the 2020 Summer Olympics'
# Fetching page 'Basketball at the 2020 Summer Olympics – Women's team rosters'
# Fetching page 'Water polo at the 2020 Summer Olympics – Men's team rosters'
# Fetching page 'Field hockey at the 2020 Summer Olympics – Women's team squads'
# Fetching page 'Water polo at the 2020 Summer Olympics – Women's team rosters'
# Fetching page 'List of rowers at the 2020 Summer Olympics'
# Fetching page 'Modern pentathlon at the 2020 Summer Olympics – Women's'
# Fetching page 'Wrestling at the 2020 Summer Olympics – U.S. Team Trials'
# Fetching page 'Modern pentathlon at the 2020 Summer Olympics – Men's'
# Fetching page 'Football at the 2020 Summer Olympics – Women's team squads'
# Fetching page 'Handball at the 2020 Summer Olympics – Women's team rosters'
# Fetching page 'List of sport climbers at the 2020 Summer Olympics'
# Fetching page 'List of athletes at the 2020 Summer Olympics'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's team rosters'
# Fetching page 'Archery at the 2020 Summer Olympics – Men's individual'
# Fetching page 'Archery at the 2020 Summer Olympics – Men's team'
# Fetching page 'Archery at the 2020 Summer Olympics - Mixed team'
# Fetching page 'Archery at the 2020 Summer Olympics – Women's team'
# Fetching page 'Archery at the 2020 Summer Olympics – Mixed team'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Women's freestyle 62 kg'
# Fetching page 'Football at the 2020 Summer Olympics – Men's tournament – Knockout stage'
# Fetching page 'Football at the 2020 Summer Olympics – Men's tournament'
# Fetching page 'Boxing at the 2020 Summer Olympics – Men's flyweight'
# Fetching page 'Rowing at the 2020 Summer Olympics – Men's eight'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's freestyle 97 kg'
# Fetching page 'Rowing at the 2020 Summer Olympics – Men's double sculls'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 400 metres'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 50 metre freestyle'
# Fetching page 'Archery at the 2020 Summer Olympics – Women's individual'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's discus throw'
# Fetching page 'Canoeing at the 2020 Summer Olympics - Men's C-1 1000 metres'
# Fetching page '2020 Summer Olympics national flag bearers'
# Fetching page 'Basketball at the 2020 Summer Olympics – Women's 3x3 tournament'
# Fetching page 'Boxing at the 2020 Summer Olympics – Women's featherweight'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Women's freestyle 50 kg'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 200 metre freestyle'
# Fetching page 'Rowing at the 2020 Summer Olympics – Women's coxless pair'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's individual road race'
# Fetching page 'Rowing at the 2020 Summer Olympics – Women's coxless four'
# Fetching page 'Judo at the 2020 Summer Olympics – Men's +100 kg'
# Fetching page 'Table tennis at the 2020 Summer Olympics – Women's singles'
# Fetching page 'Table tennis at the 2020 Summer Olympics – Men's singles'
# Fetching page 'Shooting at the 2020 Summer Olympics – Women's 10 metre air rifle'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's shot put'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's balance beam'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Women's freestyle 53 kg'
# Fetching page 'Rowing at the 2020 Summer Olympics – Men's coxless pair'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 100 metre backstroke'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 100 metre butterfly'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 100 metre freestyle'
# Fetching page 'Table tennis at the 2020 Summer Olympics – Women's team'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's long jump'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Men's C-2 1000 metres'
# Fetching page 'Fencing at the 2020 Summer Olympics – Women's épée'
# Fetching page 'Fencing at the 2020 Summer Olympics – Men's sabre'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's 50 kilometres walk'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Men's Greco-Roman 130 kg'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 50 metre freestyle'
# Fetching page 'Rowing at the 2020 Summer Olympics – Women's eight'
# Fetching page 'Football at the 2020 Summer Olympics – Men's tournament – Group B'
# Fetching page 'Tennis at the 2020 Summer Olympics – Women's doubles'
# Fetching page 'Judo at the 2020 Summer Olympics – Men's 73 kg'
# Fetching page 'Judo at the 2020 Summer Olympics – Women's 52 kg'
# Fetching page 'Rowing at the 2020 Summer Olympics – Women's double sculls'
# Fetching page 'Rowing at the 2020 Summer Olympics – Men's coxless four'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Women's artistic individual all-around'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's high jump'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's hammer throw'
# Fetching page 'Cycling at the 2020 Summer Olympics – Men's cross-country'
# Fetching page 'Table tennis at the 2020 Summer Olympics – Mixed doubles'
# Fetching page 'Swimming at the 2020 Summer Olympics – Women's 100 metre freestyle'
# Fetching page 'Athletics at the 2020 Summer Olympics – Men's javelin throw'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Men's vault'
# Fetching page 'Triathlon at the 2020 Summer Olympics – Men's'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 1500 metres'
# Fetching page 'Tennis at the 2020 Summer Olympics – Women's singles'
# Fetching page 'Rowing at the 2020 Summer Olympics – Women's lightweight double sculls'
# Fetching page 'Swimming at the 2020 Summer Olympics – Men's 200 metre backstroke'
# Fetching page 'Boxing at the 2020 Summer Olympics – Qualification'
# Fetching page 'Sport climbing at the 2020 Summer Olympics'
# Fetching page 'Sport climbing at the 2020 Summer Olympics – Men's'
# Fetching page 'Sport climbing at the 2020 Summer Olympics – Women's'
# Fetching page 'Bosnia and Herzegovina at the 2020 Summer Olympics'
# Fetching page 'Bahrain at the 2020 Summer Olympics'
# Fetching page 'Liechtenstein at the 2020 Summer Olympics'
# Fetching page 'Dominica at the 2020 Summer Olympics'
# Fetching page 'Chad at the 2020 Summer Olympics'
# Fetching page 'Senegal at the 2020 Summer Olympics'
# Fetching page 'Cameroon at the 2020 Summer Olympics'
# Fetching page 'Venues of the 2020 Summer Olympics and Paralympics'
# Fetching page 'Zambia at the 2020 Summer Olympics'
# Fetching page 'Austria at the 2020 Summer Olympics'
# Fetching page 'Cycling at the 2020 Summer Olympics'
# Fetching page 'Israel at the 2020 Summer Olympics'
# Fetching page 'Wrestling at the 2020 Summer Olympics'
# Fetching page 'Mexico at the 2020 Summer Olympics'
# Fetching page 'Palau at the 2020 Summer Olympics'
# Fetching page 'Latvia at the 2020 Summer Olympics'
# Fetching page 'Malaysia at the 2020 Summer Olympics'
# Fetching page 'Swimming at the 2020 Summer Olympics - Qualification'
# Fetching page 'Panama at the 2020 Summer Olympics'
# Fetching page 'Karate at the 2020 Summer Olympics – Qualification'
# Fetching page 'Diving at the 2020 Summer Olympics – Qualification'
# Fetching page 'Norway at the 2020 Summer Olympics'
# Fetching page 'Equestrian at the 2020 Summer Olympics - Qualification'
# Fetching page 'List of 2020 Summer Olympics broadcasters'
# Fetching page 'Field hockey at the 2020 Summer Olympics – Women's qualification'
# Fetching page 'Estonia at the 2020 Summer Olympics'
# Fetching page 'Tennis at the 2020 Summer Olympics - Qualification'
# Fetching page 'Suriname at the 2020 Summer Olympics'
# Fetching page 'Ireland at the 2020 Summer Olympics'
# Fetching page 'Trinidad and Tobago at the 2020 Summer Olympics'
# Fetching page 'Equestrian at the 2020 Summer Olympics'
# Fetching page 'Guinea-Bissau at the 2020 Summer Olympics'
# Fetching page 'Burkina Faso at the 2020 Summer Olympics'
# Fetching page 'Athletics at the 2020 Summer Olympics - Men's triple jump'
# Fetching page 'Mongolia at the 2020 Summer Olympics'
# Fetching page 'Mauritania at the 2020 Summer Olympics'
# Fetching page 'Tonga at the 2020 Summer Olympics'
# Fetching page 'Chile at the 2020 Summer Olympics'
# Fetching page 'Rowing at the 2020 Summer Olympics – Qualification'
# Fetching page 'Uzbekistan at the 2020 Summer Olympics'
# Fetching page 'Tunisia at the 2020 Summer Olympics'
# Fetching page 'Venezuela at the 2020 Summer Olympics'
# Fetching page 'Guyana at the 2020 Summer Olympics'
# Fetching page 'Poland at the 2020 Summer Olympics'
# Fetching page 'Brazil at the 2020 Summer Olympics'
# Fetching page '2020 Summer Olympics pictograms'
# Fetching page 'Shooting at the 2020 Summer Olympics – Qualification'
# Fetching page 'South Africa at the 2020 Summer Olympics'
# Fetching page 'Football at the 2020 Summer Olympics – Women's qualification'
# Fetching page 'Football at the 2020 Summer Olympics CAF–CONMEBOL play-off'
# Fetching page 'United Arab Emirates at the 2020 Summer Olympics'
# Fetching page 'Samoa at the 2020 Summer Olympics'
# Fetching page 'São Tomé and Príncipe at the 2020 Summer Olympics'
# Fetching page 'Barbados at the 2020 Summer Olympics'
# Fetching page 'Hong Kong at the 2020 Summer Olympics'
# Fetching page 'Yemen at the 2020 Summer Olympics'
# Fetching page 'Aruba at the 2020 Summer Olympics'
# Fetching page 'Modern pentathlon at the 2020 Summer Olympics'
# Fetching page 'Vietnam at the 2020 Summer Olympics'
# Fetching page 'Basketball at the 2020 Summer Olympics – Women's qualification'
# Fetching page 'IOC Refugee Olympic Team at the 2020 Summer Olympics'
# Fetching page 'Slovenia at the 2020 Summer Olympics'
# Fetching page 'Cycling at the 2020 Summer Olympics - Men's road time trial'
# Fetching page 'Judo at the 2020 Summer Olympics - Women's 63 kg'
# Fetching page 'Greece at the 2020 Summer Olympics'
# Fetching page 'Georgia at the 2020 Summer Olympics'
# Fetching page 'Great Britain at the 2020 Summer Olympics'
# Fetching page 'Swimming at the 2020 Summer Olympics - Mixed 4 × 100 metre medley relay'
# Fetching page 'Judo at the 2020 Summer Olympics - Qualification'
# Fetching page 'Russia at the 2020 Summer Olympics'
# Fetching page 'ROC at the 2020 Summer Olympics'
# Fetching page 'Haiti at the 2020 Summer Olympics'
# Fetching page 'Mali at the 2020 Summer Olympics'
# Fetching page 'Brunei at the 2020 Summer Olympics'
# Fetching page 'Central African Republic at the 2020 Summer Olympics'
# Fetching page 'Indonesia at the 2020 Summer Olympics'
# Fetching page 'Baseball at the 2020 Summer Olympics'
# Fetching page 'Namibia at the 2020 Summer Olympics'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Women's qualification'
# Fetching page 'Nigeria at the 2020 Summer Olympics'
# Fetching page 'Iceland at the 2020 Summer Olympics'
# Fetching page 'Kosovo at the 2020 Summer Olympics'
# Fetching page 'Saint Kitts and Nevis at the 2020 Summer Olympics'
# Fetching page '2020 Summer Olympics closing ceremony flag bearers'
# Fetching page 'Syria at the 2020 Summer Olympics'
# Fetching page 'Beach volleyball at the 2020 Summer Olympics – Men's qualification'
# Fetching page 'South Korea at the 2020 Summer Olympics'
# Fetching page 'Wrestling at the 2020 Summer Olympics – Qualification'
# Fetching page 'Table tennis at the 2020 Summer Olympics'
# Fetching page 'Saint Vincent and the Grenadines at the 2020 Summer Olympics'
# Fetching page 'Slovakia at the 2020 Summer Olympics'
# Fetching page 'List of athletes not attending the 2020 Summer Olympics due to COVID-19 concerns'
# Fetching page 'Handball at the 2020 Summer Olympics – Women's qualification'
# Fetching page 'Luxembourg at the 2020 Summer Olympics'
# Fetching page 'Finland at the 2020 Summer Olympics'
# Fetching page 'Gymnastics at the 2020 Summer Olympics'
# Fetching page 'Jamaica at the 2020 Summer Olympics'
# Fetching page 'Swimming at the 2020 Summer Olympics - Men's 200 metre individual medley'
# Fetching page 'Swimming at the 2020 Summer Olympics - Men's 200 metre butterfly'
# Fetching page 'Turkey at the 2020 Summer Olympics'
# Fetching page 'Water polo at the 2020 Summer Olympics'
# Fetching page 'Concerns and controversies at the 2020 Summer Olympics'
# Fetching page 'Russian Olympic Committee athletes at the 2020 Summer Olympics'
# Fetching page 'Malawi at the 2020 Summer Olympics'
# Fetching page 'Bolivia at the 2020 Summer Olympics'
# Fetching page 'Badminton at the 2020 Summer Olympics'
# Fetching page 'Badminton at the 2020 Summer Olympics - Women's doubles'
# Fetching page 'Badminton at the 2020 Summer Olympics - Mixed doubles'
# Fetching page 'Badminton at the 2020 Summer Olympics - Men's doubles'
# Fetching page 'Badminton at the 2020 Summer Olympics - Women's singles'
# Fetching page 'Portugal at the 2020 Summer Olympics'
# Fetching page 'Singapore at the 2020 Summer Olympics'
# Fetching page 'Kiribati at the 2020 Summer Olympics'
# Fetching page 'North Macedonia at the 2020 Summer Olympics'
# Fetching page 'COVID-19 cases at the 2020 Summer Olympics'
# Fetching page 'Impact of the COVID-19 pandemic on the 2020 Summer Olympics'
# Fetching page 'Saint Lucia at the 2020 Summer Olympics'
# Fetching page 'Japan at the 2020 Summer Olympics'
# Fetching page 'Cuba at the 2020 Summer Olympics'
# Fetching page 'Gabon at the 2020 Summer Olympics'
# Fetching page 'Water polo at the 2020 Summer Olympics – Men's qualification'
# Fetching page 'Taekwondo at the 2020 Summer Olympics'
# Fetching page 'The Gambia at the 2020 Summer Olympics'
# Fetching page 'Baku bid for the 2020 Summer Olympics'
# Fetching page 'Equestrian at the 2020 Summer Olympics – Qualification'
# Fetching page 'Antigua and Barbuda at the 2020 Summer Olympics'
# Fetching page 'Eswatini at the 2020 Summer Olympics'
# Fetching page 'Surfing at the 2020 Summer Olympics'
# Fetching page 'East Timor at the 2020 Summer Olympics'
# Fetching page 'Djibouti at the 2020 Summer Olympics'
# Fetching page '2020 Summer Olympics Parade of Nations'
# Fetching page 'Skateboarding at the 2020 Summer Olympics – Qualification'
# Fetching page 'Fencing at the 2020 Summer Olympics – Qualification'
# Fetching page 'Rugby sevens at the 2020 Summer Olympics – Women's qualification'
# Fetching page 'British Virgin Islands at the 2020 Summer Olympics'
# Fetching page 'Botswana at the 2020 Summer Olympics'
# Fetching page 'Andorra at the 2020 Summer Olympics'
# Fetching page 'Judo at the 2020 Summer Olympics'
# Fetching page '2020 Summer Olympics medal table'
# Fetching page 'Belize at the 2020 Summer Olympics'
# Fetching page 'Golf at the 2020 Summer Olympics – Qualification'
# Fetching page 'Bangladesh at the 2020 Summer Olympics'
# Fetching page 'Colombia at the 2020 Summer Olympics'
# Fetching page 'Swimming at the 2020 Summer Olympics'
# Fetching page 'Thailand at the 2020 Summer Olympics'
# Fetching page 'Doha bid for the 2020 Summer Olympics'
# Fetching page 'Madrid bid for the 2020 Summer Olympics'
# Fetching page 'Handball at the 2020 Summer Olympics'
# Fetching page 'Pakistan at the 2020 Summer Olympics'
# Fetching page 'Artistic swimming at the 2020 Summer Olympics'
# Fetching page 'Rugby sevens at the 2020 Summer Olympics – Men's qualification'
# Fetching page 'Boxing at the 2020 Summer Olympics'
# Fetching page 'Eritrea at the 2020 Summer Olympics'
# Fetching page 'Field hockey at the 2020 Summer Olympics – Men's qualification'
# Fetching page 'Somalia at the 2020 Summer Olympics'
# Fetching page 'Golf at the 2020 Summer Olympics'
# Fetching page 'Cycling at the 2020 Summer Olympics – Qualification'
# Fetching page 'Czech Republic at the 2020 Summer Olympics'
# Fetching page 'Tennis at the 2020 Summer Olympics – Women's Singles'
# Fetching page 'Rowing at the 2020 Summer Olympics'
# Fetching page 'Maldives at the 2020 Summer Olympics'
# Fetching page 'Athletics at the 2020 Summer Olympics'
# Fetching page 'Guatemala at the 2020 Summer Olympics'
# Fetching page 'Weightlifting at the 2020 Summer Olympics - Qualification'
# Fetching page 'Field hockey at the 2020 Summer Olympics'
# Fetching page 'Myanmar at the 2020 Summer Olympics'
# Fetching page 'Taekwondo at the 2020 Summer Olympics – Qualification'
# Fetching page 'China at the 2020 Summer Olympics'
# Fetching page 'Cook Islands at the 2020 Summer Olympics'
# Fetching page 'Benin at the 2020 Summer Olympics'
# Fetching page 'Uganda at the 2020 Summer Olympics'
# Fetching page 'Tennis at the 2020 Summer Olympics – Qualification'
# Fetching page 'Paraguay at the 2020 Summer Olympics'
# Fetching page 'Weightlifting at the 2020 Summer Olympics'
# Fetching page 'Rwanda at the 2020 Summer Olympics'
# Fetching page 'Beach volleyball at the 2020 Summer Olympics – Women's qualification'
# Fetching page 'Marshall Islands at the 2020 Summer Olympics'
# Fetching page 'Cyprus at the 2020 Summer Olympics'
# Fetching page 'Sailing at the 2020 Summer Olympics'
# Fetching page 'Croatia at the 2020 Summer Olympics'
# Fetching page 'Ecuador at the 2020 Summer Olympics'
# Fetching page 'Sport climbing at the 2020 Summer Olympics – Qualification'
# Fetching page 'Tajikistan at the 2020 Summer Olympics'
# Fetching page '2020 Summer Olympics opening ceremony'
# Fetching page '2020 Summer Olympics cauldron'
# Fetching page 'Tennis at the 2020 Summer Olympics'
# Fetching page 'Tennis at the 2020 Summer Olympics – Day-by-day summaries'
# Fetching page 'Spain at the 2020 Summer Olympics'
# Fetching page 'Weightlifting at the 2020 Summer Olympics – Qualification'
# Fetching page 'Argentina at the 2020 Summer Olympics'
# Fetching page 'Democratic Republic of the Congo at the 2020 Summer Olympics'
# Fetching page 'Canada at the 2020 Summer Olympics'
# Fetching page 'Ukraine at the 2020 Summer Olympics'
# Fetching page 'India at the 2020 Summer Olympics'
# Fetching page 'Lebanon at the 2020 Summer Olympics'
# Fetching page 'Morocco at the 2020 Summer Olympics'
# Fetching page 'Peru at the 2020 Summer Olympics'
# Fetching page 'Switzerland at the 2020 Summer Olympics'
# Fetching page 'Guam at the 2020 Summer Olympics'
# Fetching page 'Chinese Taipei at the 2020 Summer Olympics'
# Fetching page 'Ghana at the 2020 Summer Olympics'
# Fetching page 'Australia at the 2020 Summer Olympics'
# Fetching page 'Oman at the 2020 Summer Olympics'
# Fetching page 'Tokyo bid for the 2020 Summer Olympics'
# Fetching page 'Italy at the 2020 Summer Olympics'
# Fetching page 'Armenia at the 2020 Summer Olympics'
# Fetching page 'Bhutan at the 2020 Summer Olympics'
# Fetching page 'Netherlands at the 2020 Summer Olympics'
# Fetching page 'Kyrgyzstan at the 2020 Summer Olympics'
# Fetching page 'Diving at the 2020 Summer Olympics'
# Fetching page 'Niger at the 2020 Summer Olympics'
# Fetching page 'Liberia at the 2020 Summer Olympics'
# Fetching page 'Handball at the 2020 Summer Olympics – Men's qualification'
# Fetching page 'Bahamas at the 2020 Summer Olympics'
# Fetching page 'Athletics at the 2020 Summer Olympics - Women's 400 metres'
# Fetching page 'Volleyball at the 2020 Summer Olympics'
# Fetching page 'Comoros at the 2020 Summer Olympics'
# Fetching page 'Malta at the 2020 Summer Olympics'
# Fetching page 'New Zealand at the 2020 Summer Olympics'
# Fetching page 'Bermuda at the 2020 Summer Olympics'
# Fetching page 'Shooting at the 2020 Summer Olympics'
# Fetching page 'South Sudan at the 2020 Summer Olympics'
# Fetching page 'Kuwait at the 2020 Summer Olympics'
# Fetching page 'France at the 2020 Summer Olympics'
# Fetching page 'Istanbul bid for the 2020 Summer Olympics'
# Fetching page 'Egypt at the 2020 Summer Olympics'
# Fetching page 'Tanzania at the 2020 Summer Olympics'
# Fetching page 'Artistic swimming at the 2020 Summer Olympics – Qualification'
# Fetching page 'Republic of the Congo at the 2020 Summer Olympics'
# Fetching page 'Laos at the 2020 Summer Olympics'
# Fetching page 'San Marino at the 2020 Summer Olympics'
# Fetching page 'Nauru at the 2020 Summer Olympics'
# Fetching page 'Bids for the 2020 Summer Olympics'
# Fetching page 'Dominican Republic at the 2020 Summer Olympics'
# Fetching page 'Libya at the 2020 Summer Olympics'
# Fetching page 'Iran at the 2020 Summer Olympics'
# Fetching page 'Guinea at the 2020 Summer Olympics'
# Fetching page 'Bulgaria at the 2020 Summer Olympics'
# Fetching page 'Judo at the 2020 Summer Olympics – Qualification'
# Fetching page 'Fencing at the 2020 Summer Olympics'
# Fetching page 'Ivory Coast at the 2020 Summer Olympics'
# Fetching page 'Karate at the 2020 Summer Olympics'
# Fetching page 'Belarus 2020 Summer Olympics scandal'
# Fetching page 'Basketball at the 2020 Summer Olympics – Women's 3x3 qualification'
# Fetching page 'Lesotho at the 2020 Summer Olympics'
# Fetching page 'Tuvalu at the 2020 Summer Olympics'
# Fetching page 'Azerbaijan at the 2020 Summer Olympics'
# Fetching page 'Shooting at the 2020 Summer Olympics - Men's skeet'
# Fetching page 'Iraq at the 2020 Summer Olympics'
# Fetching page 'Seychelles at the 2020 Summer Olympics'
# Fetching page 'Madagascar at the 2020 Summer Olympics'
# Fetching page 'Papua New Guinea at the 2020 Summer Olympics'
# Fetching page 'Afghanistan at the 2020 Summer Olympics'
# Fetching page 'Cambodia at the 2020 Summer Olympics'
# Fetching page 'Montenegro at the 2020 Summer Olympics'
# Fetching page 'List of 2020 Summer Olympics medal winners'
# Fetching page 'Rome bid for the 2020 Summer Olympics'
# Fetching page 'Marathon swimming at the 2020 Summer Olympics'
# Fetching page 'Athletics at the 2020 Summer Olympics – Qualification'
# Fetching page 'Burundi at the 2020 Summer Olympics'
# Fetching page 'Modern pentathlon at the 2020 Summer Olympics – Qualification'
# Fetching page 'Water polo at the 2020 Summer Olympics – Women's qualification'
# Fetching page 'Qatar at the 2020 Summer Olympics'
# Fetching page 'Athletics at the 2020 Summer Olympics - Men's 1500 metres'
# Fetching page 'Basketball at the 2020 Summer Olympics'
# Fetching page 'Philippines at the 2020 Summer Olympics'
# Fetching page 'Nepal at the 2020 Summer Olympics'
# Fetching page 'Sierra Leone at the 2020 Summer Olympics'
# Fetching page 'Gymnastics at the 2020 Summer Olympics – Qualification'
# Fetching page 'FIG Artistic Gymnastics World Cup series – 2020 Summer Olympics Qualification'
# Fetching page '2020 Summer Olympics marketing'
# Fetching page 'Softball at the 2020 Summer Olympics'
# Fetching page '2020 Summer Olympics development'
# Fetching page 'American Samoa at the 2020 Summer Olympics'
# Fetching page 'Kenya at the 2020 Summer Olympics'
# Fetching page 'Athletics at the 2020 Summer Olympics – Women's 100 metres'
# Fetching page 'Cycling at the 2020 Summer Olympics – Women's cross-country'
# Fetching page 'Swimming at the 2020 Summer Olympics – Qualification'
# Fetching page 'Canoeing at the 2020 Summer Olympics – Qualification'
# Fetching page 'Costa Rica at the 2020 Summer Olympics'
# Fetching page 'Hungary at the 2020 Summer Olympics'
# Fetching page 'Canoeing at the 2020 Summer Olympics - Women's K-4 500 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics - Women's C-1 200 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics - Women's K-2 500 metres'
# Fetching page 'Canoeing at the 2020 Summer Olympics - Men's K-1 200 metres'
# Fetching page 'Saudi Arabia at the 2020 Summer Olympics'
# Fetching page 'Honduras at the 2020 Summer Olympics'
# Fetching page 'Table tennis at the 2020 Summer Olympics – Qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's qualification'
# Fetching page 'Volleyball at the 2020 Summer Olympics – Men's Intercontinental qualification'
# Fetching page 'Sweden at the 2020 Summer Olympics'
# Fetching page 'Belarus at the 2020 Summer Olympics'
# Fetching page 'Surfing at the 2020 Summer Olympics – Qualification'
# Fetching page 'Skateboarding at the 2020 Summer Olympics'
# Fetching page 'Albania at the 2020 Summer Olympics'
# Fetching page 'Triathlon at the 2020 Summer Olympics – Qualification'
# Fetching page 'Germany at the 2020 Summer Olympics'
# Fetching page 'Federated States of Micronesia at the 2020 Summer Olympics'
# Fetching page 'Triathlon at the 2020 Summer Olympics'
# Fetching page 'United States at the 2020 Summer Olympics'
# Fetching page 'Baseball at the 2020 Summer Olympics – Qualification'
# Fetching page '2020 Summer Olympics torch relay'
# Fetching page 'Belgium at the 2020 Summer Olympics'
# Fetching page 'Skateboarding at the 2020 Summer Olympics – Nen’s street'
# Fetching page 'Skateboarding at the 2020 Summer Olympics – Women’s street'
# Fetching page 'Archery at the 2020 Summer Olympics – Qualification'
# Fetching page 'Monaco at the 2020 Summer Olympics'
# Fetching page 'Basketball at the 2020 Summer Olympics – Men's 3x3 qualification'
# Fetching page 'Nicaragua at the 2020 Summer Olympics'
# Fetching page 'Mauritius at the 2020 Summer Olympics'
# Fetching page 'Angola at the 2020 Summer Olympics'
# Fetching page 'Togo at the 2020 Summer Olympics'
# Fetching page 'Turkmenistan at the 2020 Summer Olympics'
# Fetching page 'Chronological summary of the 2020 Summer Olympics'
# Fetching page 'Moldova at the 2020 Summer Olympics'
# Fetching page 'Refugee Olympic Team at the 2020 Summer Olympics'
# Fetching page 'Sri Lanka at the 2020 Summer Olympics'
# Fetching page 'Sailing at the 2020 Summer Olympics – Qualification'
# Fetching page 'Archery at the 2020 Summer Olympics'
# Fetching page 'Badminton at the 2020 Summer Olympics – Qualification'
# Fetching page 'El Salvador at the 2020 Summer Olympics'
# Fetching page 'Lithuania at the 2020 Summer Olympics'
# Fetching page 'Solomon Islands at the 2020 Summer Olympics'
# Fetching page 'Equatorial Guinea at the 2020 Summer Olympics'
# Fetching page 'Grenada at the 2020 Summer Olympics'
# Fetching page 'Kazakhstan at the 2020 Summer Olympics'
# Fetching page 'Sudan at the 2020 Summer Olympics'
# Fetching page 'Ethiopia at the 2020 Summer Olympics'
# Fetching page '2020 Summer Olympic and Paralympic Games mascots'
# Fetching page 'Fiji at the 2020 Summer Olympics'
# Fetching page 'Algeria at the 2020 Summer Olympics'
# Fetching page 'Denmark at the 2020 Summer Olympics'
# Fetching page '2020 Summer Olympics closing ceremony'
# Fetching page 'Rugby sevens at the 2020 Summer Olympics'
# Fetching page 'Softball at the 2020 Summer Olympics – Qualification'
# Fetching page 'COVID-19 cases at the 2020 Summer Olympics and 2020 Summer Paralympics'
# Fetching page 'Football at the 2020 Summer Olympics'
# Fetching page 'Uruguay at the 2020 Summer Olympics'
# Fetching page 'Cayman Islands at the 2020 Summer Olympics'
# Fetching page 'Zimbabwe at the 2020 Summer Olympics'
# Fetching page 'Palestine at the 2020 Summer Olympics'
# Fetching page 'Canoeing at the 2020 Summer Olympics'
# Fetching page 'Virgin Islands at the 2020 Summer Olympics'
# Fetching page 'Cape Verde at the 2020 Summer Olympics'
# Fetching page 'World and Olympic records set at the 2020 Summer Olympics'
# Fetching page 'Jordan at the 2020 Summer Olympics'
# Fetching page 'Vanuatu at the 2020 Summer Olympics'
# Fetching page 'Basketball at the 2020 Summer Olympics – Men's qualification'
# Fetching page 'Mozambique at the 2020 Summer Olympics'
# Fetching page 'Puerto Rico at the 2020 Summer Olympics'
# Fetching page 'Serbia at the 2020 Summer Olympics'
# Fetching page 'Football at the 2020 Summer Olympics – Men's qualification'
# 691

# %%
# This could be a class that defines which tokenized to use when an instance is created.

tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")

def count_tokens(text: str) -> int:
    """count the number of tokens in a string"""
    return len(tokenizer.encode(text))

def reduce_long(
    long_text: str, long_text_tokens: bool = False, max_len: int = 590
) -> str:
    """
    Reduce a long text to a maximum of `max_len` tokens by potentially cutting at a sentence end
    """
    if not long_text_tokens:
        long_text_tokens = count_tokens(long_text)
    if long_text_tokens > max_len:
        sentences = sent_tokenize(long_text.replace("\n", " "))
        ntokens = 0
        for i, sentence in enumerate(sentences):
            ntokens += 1 + count_tokens(sentence)
            if ntokens > max_len:
                return ". ".join(sentences[:i][:-1]) + "."

    return long_text

def extract_sections(
    wiki_text: str,
    title: str,
    max_len: int = 1500,
    discard_categories: Set[str] = discard_categories,
) -> str:
    """
    Extract the sections of a Wikipedia page, discarding the references and other low information sections
    """
    if len(wiki_text) == 0:
        return []

    # find all headings and the coresponding contents
    headings = re.findall("==+ .* ==+", wiki_text)
    for heading in headings:
        wiki_text = wiki_text.replace(heading, "==+ !! ==+")
    contents = wiki_text.split("==+ !! ==+")
    contents = [c.strip() for c in contents]
    assert len(headings) == len(contents) - 1

    cont = contents.pop(0).strip()
    outputs = [(title, "Summary", cont, count_tokens(cont)+4)]
    
    # discard the discard categories, accounting for a tree structure
    max_level = 100
    keep_group_level = max_level
    remove_group_level = max_level
    nheadings, ncontents = [], []
    for heading, content in zip(headings, contents):
        plain_heading = " ".join(heading.split(" ")[1:-1])
        num_equals = len(heading.split(" ")[0])
        if num_equals <= keep_group_level:
            keep_group_level = max_level

        if num_equals > remove_group_level:
            if (
                num_equals <= keep_group_level
            ):
                continue
        keep_group_level = max_level
        if plain_heading in discard_categories:
            remove_group_level = num_equals
            keep_group_level = max_level
            continue
        nheadings.append(heading.replace("=", "").strip())
        ncontents.append(content)
        remove_group_level = max_level

    # count the tokens of each section
    ncontent_ntokens = [
        count_tokens(c)
        + 3
        + count_tokens(" ".join(h.split(" ")[1:-1]))
        - (1 if len(c) == 0 else 0)
        for h, c in zip(nheadings, ncontents)
    ]

    # Create a tuple of (title, section_name, content, number of tokens)
    outputs += [(title, h, c, t) if t<max_len 
                else (title, h, reduce_long(c, max_len), count_tokens(reduce_long(c,max_len))) 
                    for h, c, t in zip(nheadings, ncontents, ncontent_ntokens)]
    
    return outputs

# %%
# Example page being processed into sections

discard_oly_categories = ['See also', 'References', 'External links', 'Further reading', "Footnotes",
    "Bibliography", "Sources", "Citations", "Literature", "Footnotes", "Notes and references",
    "Photo gallery", "Works cited", "Photos", "Gallery", "Notes", "References and sources",
    "References and notes",]

bermuda_page = get_wiki_page('Bermuda at the 2020 Summer Olympics')
ber = extract_sections(bermuda_page.content, bermuda_page.title, discard_categories=discard_oly_categories)

for section in ber:
    print('\nSection:\n')
    print(section)
# Out:
# Fetching page 'Bermuda at the 2020 Summer Olympics'
#
# Section:
#
# ('Bermuda at the 2020 Summer Olympics', 'Summary', "Bermuda competed at the 2020 Summer Olympics in Tokyo. Originally scheduled to take place from 24 July to 9 August 2020, the Games had been postponed to 23 July to 8 August 2021, because of the COVID-19 pandemic. Since the nation's official debut in 1936, Bermudian athletes have appeared in every edition of the Summer Olympic Games, but did not attend the 1980 Summer Olympics in Moscow because of the nation's support for the US-led boycott.\nThe first ever gold medal for Bermuda was won by triathlete Flora Duffy.", 117)
#
# Section:
#
# ('Bermuda at the 2020 Summer Olympics', 'Medalists', '', 2)
#
# Section:
#
# ('Bermuda at the 2020 Summer Olympics', 'Competitors', 'The following is the list of number of competitors in the Games.', 16)
#
# Section:
#
# ('Bermuda at the 2020 Summer Olympics', 'Rowing', "Bermuda qualified one boat in the men's single sculls for the Games by finishing third in the B-final and securing the second of five berths available at the 2021 FISA Americas Olympic Qualification Regatta in Rio de Janeiro, Brazil.\nQualification Legend: FA=Final A (medal); FB=Final B (non-medal); FC=Final C (non-medal); FD=Final D (non-medal); FE=Final E (non-medal); FF=Final F (non-medal); SA/B=Semifinals A/B; SC/D=Semifinals C/D; SE/F=Semifinals E/F; QF=Quarterfinals; R=Repechage", 162)
#
# Section:
#
# ('Bermuda at the 2020 Summer Olympics', 'Triathlon', "Bermuda entered one triathlete to compete at the Olympics. Remarkably going to her historic fourth Games, Flora Duffy was selected among the top 26 triathletes vying for qualification in the women's event based on the individual ITU World Rankings of 15 June 2021. She won the Gold Medal.", 66)
#
# Section:
#
# ('Bermuda at the 2020 Summer Olympics', 'Non-competing sports', '', 2)
#
# Section:
#
# ('Bermuda at the 2020 Summer Olympics', 'Equestrian', "Bermuda entered one dressage rider into the Olympic competition by finishing in the top four, outside the group selection, of the individual FEI Olympic Rankings for Groups D and E (North, Central, and South America), marking the country's recurrence to the sport after an eight-year absence. The quota was later withdrawn, following an injury of Annabelle Collins' main horse Joyero and a failure to obtain minimum eligibility requirements (MER) aboard a new horse Chuppy Checker.", 104)

# %%
# Build a data set from the wikipedia page sections

res = []
for page in pages:
    res += extract_sections(page.content, page.title, discard_categories=discard_oly_categories)
df = pd.DataFrame(res, columns=["title", "heading", "content", "tokens"])
df = df[df.tokens>40]
df = df.drop_duplicates(['title','heading'])
df = df.reset_index().drop('index',axis=1) # reset index
df.head()

df.to_csv('olympics-data/summer_olympics_sections.csv', index=False)
df
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1073 > 1024). Running this sequence through the model will result in indexing errors
#                                                   title  \
# 0                                  2020 Summer Olympics
# 1                                  2020 Summer Olympics
# 2                                  2020 Summer Olympics
# 3                                  2020 Summer Olympics
# 4                                  2020 Summer Olympics
# ...                                                 ...
# 3689                 Serbia at the 2020 Summer Olympics
# 3690                 Serbia at the 2020 Summer Olympics
# 3691                 Serbia at the 2020 Summer Olympics
# 3692                 Serbia at the 2020 Summer Olympics
# 3693  Football at the 2020 Summer Olympics – Men's q...
#
#                                              heading  \
# 0                                            Summary
# 1                                Host city selection
# 2                    Impact of the COVID-19 pandemic
# 3     Qualifying event cancellation and postponement
# 4                             Effect on doping tests
# ...                                              ...
# 3689                                    Table tennis
# 3690                                       Taekwondo
# 3691                                          Tennis
# 3692                                       Wrestling
# 3693                                         Summary
#
#                                                 content  tokens
# 0     The 2020 Summer Olympics (Japanese: 2020年夏季オリン...     753
# 1     The International Olympic Committee (IOC) vote...     126
# 2     In January 2020, concerns were raised about th...     374
# 3     Concerns about the pandemic began to affect qu...     298
# 4     Mandatory doping tests were being severely res...     163
# ...                                                 ...     ...
# 3689  Serbia entered three athletes into the table t...      62
# 3690  Serbia entered two athletes into the taekwondo...      80
# 3691  Serbia entered five tennis players into the Ol...     106
# 3692  Serbia qualified four wrestlers for each of th...     110
# 3693  There will be 16 teams that qualify for the me...      41
#
# [3694 rows x 4 columns]

# %%
# The number of tokens processable by gpt2 is 1024
# I'm not sure what the downstream effects of these might be 
df[df['tokens'] > 1024].sort_values('tokens', ascending=False)
# Out:
#                                                   title  \
# 1647              Venezuela at the 2020 Summer Olympics
# 28                                 2020 Summer Olympics
# 2071  Concerns and controversies at the 2020 Summer ...
# 3153  Athletics at the 2020 Summer Olympics – Qualif...
# 1039  Cycling at the 2020 Summer Olympics – Men's in...
# 15                                 2020 Summer Olympics
#
#                                           heading  \
# 1647                             Men's tournament
# 28                     Concerns and controversies
# 2071  COVID-19 pandemic and other contagion risks
# 3153                         Qualifying standards
# 1039                                Race overview
# 15                          Biosecurity protocols
#
#                                                 content  tokens
# 1647  Venezuela men's volleyball team qualified for ...    1457
# 28    Several controversial issues occurred during t...    1398
# 2071  The COVID-19 (coronavirus disease 2019) pandem...    1339
# 3153  A National Olympic Committee (NOC) may enter u...    1260
# 1039  As soon as the race started, a group of eight ...    1226
# 15    In February 2021, the IOC began releasing "pla...    1076

# %%
# It seems like all of this could be consolidated into a pretty versitile package for 
# extracting data from wikipedia on a given topic.
